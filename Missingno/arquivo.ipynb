# %% [markdown]
# La libreria `missingno` di Python è un'ottima soluzione per visualizzare e analizzare i dati mancanti (missing data) in un DataFrame. Permette di esplorare facilmente la distribuzione e il pattern dei valori mancanti in un dataset, facilitando il processo di pulizia dei dati.
#
# ### Installazione
#
# Per installare `missingno`, puoi usare `pip`:

# %%
# !pip install missingno

# %%
import missingno as msno
import pandas as pd

# %%
df = pd.read_csv("animal-data-1.csv")

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10290 entries, 0 to 10289
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                10290 non-null  int64
#  1   intakedate        10290 non-null  object
#  2   intakereason      10288 non-null  object
#  3   istransfer        10290 non-null  int64
#  4   sheltercode       10290 non-null  object
#  5   identichipnumber  8324 non-null   object
#  6   animalname        10290 non-null  object
#  7   breedname         10245 non-null  object
#  8   basecolour        10290 non-null  object
#  9   speciesname       10290 non-null  object
#  10  animalage         10290 non-null  object
#  11  sexname           10290 non-null  object
#  12  location          10290 non-null  object
#  13  movementdate      10290 non-null  object
#  14  movementtype      10290 non-null  object
#  15  istrial           10289 non-null  float64
# ...

# %% [markdown]
# ### Funzioni principali
#
# 1. **Visualizzare la distribuzione dei dati mancanti**
#     - `missingno.matrix()`: Visualizza una matrice che mostra la posizione dei valori mancanti. I valori presenti sono mostrati in bianco, mentre i valori mancanti sono in nero. Questo aiuta a capire se ci sono schemi nei dati mancanti.

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# 2. **Heatmap dei dati mancanti**
#     - `missingno.heatmap()`: Crea una heatmap che mostra le correlazioni tra le colonne basate sulla presenza o assenza di dati. Se due colonne hanno valori mancanti nello stesso record, sono correlate, e la heatmap lo evidenzia.

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %% [markdown]
# 3. **Visualizzare la distribuzione delle assenze**
#     - `missingno.dendrogram()`: Visualizza un dendrogramma per raggruppare le colonne in base alla correlazione tra i valori mancanti.
#     ```

# %%
msno.dendrogram(df)
# Out:
# <Axes: >

# %% [markdown]
# 4. **Bar plot della percentuale di valori mancanti**
#     - `missingno.bar()`: Mostra un grafico a barre della percentuale di dati mancanti in ogni colonna.

# %%
msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# 5. **Distribuzione dei dati mancanti per singolo valore**
#     - `missingno.nullity_filter()`: Mostra un filtro che ti permette di visualizzare quali colonne o righe hanno la percentuale più alta di dati mancanti.

# %%
msno.nullity_filter(df)
# Out:
#           id           intakedate           intakereason  istransfer  \
# 0      15801  2009-11-28 00:00:00                 Moving           0
# 1      15932  2009-12-08 00:00:00                 Moving           0
# 2      28859  2012-08-10 00:00:00              Abandoned           0
# 3      30812  2013-01-11 00:00:00              Abandoned           0
# 4      30812  2013-01-11 00:00:00              Abandoned           0
# ...      ...                  ...                    ...         ...
# 10285  64584  2019-08-27 16:52:09  Litter relinquishment           0
# 10286  64588  2019-08-27 18:14:11                  Stray           0
# 10287  64606  2019-08-29 12:10:21                  Stray           0
# 10288  64608  2019-08-29 18:58:06                  Stray           0
# 10289  64609  2019-08-30 10:22:37                  Stray           0
#
#       sheltercode identichipnumber       animalname                breedname  \
# ...

# %% [markdown]
# ### Vantaggi di `missingno`
#
# - Semplicità: Visualizzazioni intuitive e facili da interpretare.
# - Correlazioni: Ti aiuta a capire se i dati mancanti sono distribuiti in modo casuale o seguono uno schema.
# - Integrazione con Pandas: Funziona direttamente con i DataFrame di Pandas.
#
# Questa libreria è particolarmente utile quando hai a che fare con dataset contenenti valori mancanti e vuoi esplorare rapidamente come gestirli.
